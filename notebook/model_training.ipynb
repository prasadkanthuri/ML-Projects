# %% [markdown]
# ### Importing necessary packages

# %%
# Basic Import
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt 
import seaborn as sns
# Modelling
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.neighbors import KNeighborsRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor,AdaBoostRegressor
from sklearn.svm import SVR
from sklearn.linear_model import LinearRegression, Ridge,Lasso
from sklearn.metrics import r2_score, mean_absolute_error, mean_squared_error
from sklearn.model_selection import RandomizedSearchCV
from catboost import CatBoostRegressor
from xgboost import XGBRegressor
import warnings

# %% [markdown]
# ### Importing the data

# %%
df = pd.read_csv('data/stud.csv')
df.head(3)
# Out:
#    gender race_ethnicity parental_level_of_education     lunch  \
# 0  female        group B           bachelor's degree  standard
# 1  female        group C                some college  standard
# 2  female        group B             master's degree  standard
#
#   test_preparation_course  math_score  reading_score  writing_score
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93

# %%
### Preparing X and Y variables
X = df.drop(columns=['math_score'],axis=1)
y = df['math_score']

# %%
# Creating column transformers with 3 types of transformers. 
num_featutres = X.select_dtypes(exclude='object').columns
cate_features = X.select_dtypes(include='object').columns
print(num_featutres)
print(cate_features)
# Out:
# Index(['reading_score', 'writing_score'], dtype='object')
# Index(['gender', 'race_ethnicity', 'parental_level_of_education', 'lunch',
#        'test_preparation_course'],
#       dtype='object')

# %%
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.compose import ColumnTransformer

numeric_transformers = StandardScaler()
categorical_transformers = OneHotEncoder()
preprocesor = ColumnTransformer(
    [("numeric_transformers",numeric_transformers,num_featutres),
     ("categorical_transformers",categorical_transformers,cate_features)

    ]

)

# %%
X = preprocesor.fit_transform(X)
X.shape
# Out:
# (1000, 19)

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X,y,random_state=23,test_size=0.2)
print(X_train.shape,y_train.shape)
# Out:
# (800, 19) (800,)

# %%
# Evaluation metric 
def evaluate_model(true, predicted):
    mae = mean_absolute_error(true, predicted)
    mse = mean_squared_error(true, predicted)
    rmse = np.sqrt(mean_squared_error(true, predicted))
    r2_square = r2_score(true, predicted)
    return mae, rmse, r2_square

# %%
models = {
    "Linear Regression": LinearRegression(),
    "Lasso": Lasso(),
    "Ridge": Ridge(),
    "K-Neighbors Regressor": KNeighborsRegressor(),
    "Decision Tree": DecisionTreeRegressor(),
    "Random Forest Regressor": RandomForestRegressor(),
    "XGBRegressor": XGBRegressor(), 
    "CatBoosting Regressor": CatBoostRegressor(verbose=False),
    "AdaBoost Regressor": AdaBoostRegressor()
}
model_list = []
r2_list =[]

for i in range(len(list(models))):
    model = list(models.values())[i]
    model.fit(X_train, y_train) # Train model

    # Make predictions
    y_train_pred = model.predict(X_train)
    y_test_pred = model.predict(X_test)
    
    # Evaluate Train and Test dataset
    model_train_mae , model_train_rmse, model_train_r2 = evaluate_model(y_train, y_train_pred)

    model_test_mae , model_test_rmse, model_test_r2 = evaluate_model(y_test, y_test_pred)

    
    print(list(models.keys())[i])
    model_list.append(list(models.keys())[i])
    
    print('Model performance for Training set')
    print("- Root Mean Squared Error: {:.4f}".format(model_train_rmse))
    print("- Mean Absolute Error: {:.4f}".format(model_train_mae))
    print("- R2 Score: {:.4f}".format(model_train_r2))

    print('----------------------------------')
    
    print('Model performance for Test set')
    print("- Root Mean Squared Error: {:.4f}".format(model_test_rmse))
    print("- Mean Absolute Error: {:.4f}".format(model_test_mae))
    print("- R2 Score: {:.4f}".format(model_test_r2))
    r2_list.append(model_test_r2)
    
    print('='*35)
    print('\n')
# Out:
# Linear Regression
# Model performance for Training set
# - Root Mean Squared Error: 5.2592
# - Mean Absolute Error: 4.1681
# - R2 Score: 0.8815
# ----------------------------------
# Model performance for Test set
# - Root Mean Squared Error: 5.6218
# - Mean Absolute Error: 4.5734
# - R2 Score: 0.8524
# ===================================
#
#
# Lasso
# Model performance for Training set
# - Root Mean Squared Error: 6.5500
# - Mean Absolute Error: 5.1997
# - R2 Score: 0.8162
# ----------------------------------
# Model performance for Test set
# - Root Mean Squared Error: 6.5967
# - Mean Absolute Error: 5.1005
# - R2 Score: 0.7967
# ===================================
#
#
# Ridge
# Model performance for Training set
# - Root Mean Squared Error: 5.2594
# - Mean Absolute Error: 4.1672
# - R2 Score: 0.8815
# ----------------------------------
# Model performance for Test set
# - Root Mean Squared Error: 5.6191
# - Mean Absolute Error: 4.5672
# - R2 Score: 0.8525
# ===================================
#
#
# K-Neighbors Regressor
# Model performance for Training set
# - Root Mean Squared Error: 5.7575
# - Mean Absolute Error: 4.5620
# - R2 Score: 0.8580
# ----------------------------------
# Model performance for Test set
# - Root Mean Squared Error: 7.1297
# - Mean Absolute Error: 5.7600
# - R2 Score: 0.7626
# ===================================
#
#
# Decision Tree
# Model performance for Training set
# - Root Mean Squared Error: 0.1250
# - Mean Absolute Error: 0.0063
# - R2 Score: 0.9999
# ----------------------------------
# Model performance for Test set
# - Root Mean Squared Error: 8.8986
# - Mean Absolute Error: 7.2450
# - R2 Score: 0.6301
# ===================================
#
#
# Random Forest Regressor
# Model performance for Training set
# - Root Mean Squared Error: 2.2254
# - Mean Absolute Error: 1.7521
# - R2 Score: 0.9788
# ----------------------------------
# Model performance for Test set
# - Root Mean Squared Error: 6.4629
# - Mean Absolute Error: 5.1297
# - R2 Score: 0.8049
# ===================================
#
#
# XGBRegressor
# Model performance for Training set
# - Root Mean Squared Error: 0.9723
# - Mean Absolute Error: 0.6651
# - R2 Score: 0.9959
# ----------------------------------
# Model performance for Test set
# - Root Mean Squared Error: 6.6237
# - Mean Absolute Error: 5.2914
# - R2 Score: 0.7951
# ===================================
#
#
# CatBoosting Regressor
# Model performance for Training set
# - Root Mean Squared Error: 2.9466
# - Mean Absolute Error: 2.3107
# - R2 Score: 0.9628
# ----------------------------------
# Model performance for Test set
# - Root Mean Squared Error: 6.3189
# - Mean Absolute Error: 5.0462
# - R2 Score: 0.8135
# ===================================
#
#
# AdaBoost Regressor
# Model performance for Training set
# - Root Mean Squared Error: 5.9150
# - Mean Absolute Error: 4.8193
# - R2 Score: 0.8501
# ----------------------------------
# Model performance for Test set
# - Root Mean Squared Error: 6.5297
# - Mean Absolute Error: 5.0776
# - R2 Score: 0.8008
# ===================================

# %%
pd.DataFrame(list(zip(model_list, r2_list)), columns=['Model Name', 'R2_Score']).sort_values(by=["R2_Score"],ascending=False)
# Out:
#                 Model Name  R2_Score
# 2                    Ridge  0.852517
# 0        Linear Regression  0.852377
# 7    CatBoosting Regressor  0.813493
# 5  Random Forest Regressor  0.804895
# 8       AdaBoost Regressor  0.800844
# 1                    Lasso  0.796734
# 6             XGBRegressor  0.795065
# 3    K-Neighbors Regressor  0.762562
# 4            Decision Tree  0.630127
